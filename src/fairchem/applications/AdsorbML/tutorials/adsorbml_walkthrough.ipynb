# %%
from fairchem.core import FAIRChemCalculator
import ase.io
from ase.optimize import LBFGS

from fairchem.data.oc.core import Adsorbate, AdsorbateSlabConfig, Bulk, Slab
import os
from glob import glob
import pandas as pd
from fairchem.data.oc.utils.vasp import write_vasp_input_files

# %% [markdown]
# ## Define desired adsorbate+slab system

# %%
bulk_src_id = "mp-30"
adsorbate_smiles = "*CO"

bulk = Bulk(bulk_src_id_from_db = bulk_src_id)
adsorbate = Adsorbate(adsorbate_smiles_from_db=adsorbate_smiles)
slabs = Slab.from_bulk_get_specific_millers(bulk = bulk, specific_millers=(1,1,1))

# There may be multiple slabs with this miller index.
# For demonstrative purposes we will take the first entry.
slab = slabs[0]

# %% [markdown]
# # AdsorbML

# %%
calc = FAIRChemCalculator(hf_hub_filename="uma_sm.pt", device="cuda", task_name="oc20")
adsorption_energy_model = False

# %% [markdown]
# ### Automated
#
# More details on the automated pipeline can be found at https://github.com/facebookresearch/fairchem/blob/main/src/fairchem/core/components/calculate/recipes/adsorbml.py#L316.

# %%
from fairchem.core.components.calculate.recipes.adsorbml import run_adsorbml

outputs = run_adsorbml(
    slab=slab,
    adsorbate=adsorbate,
    calculator=calc,
    optimizer_cls=LBFGS,
    fmax=0.02,
    steps=20,         # Increase to 200 for practical application, 20 is used for demonstrations
    num_placements=10, # Increase to 100 for practical application, 10 is used for demonstrations
    reference_ml_energies=not adsorption_energy_model, #True if using a total energy model (i.e. UMA)
    relaxed_slab_atoms=None,
    place_on_relaxed_slab=False,
)
# Out:
#        Step     Time          Energy          fmax
# LBFGS:    0 15:21:19     -300.187740        0.048987
# LBFGS:    1 15:21:19     -300.188282        0.046745
# LBFGS:    2 15:21:19     -300.194195        0.005680
#        Step     Time          Energy          fmax
# LBFGS:    0 15:21:19     -333.950279        2.272333
# LBFGS:    1 15:21:19     -334.014906        1.085944
# LBFGS:    2 15:21:20     -334.051695        0.802282
# LBFGS:    3 15:21:20     -334.168344        1.425189
# LBFGS:    4 15:21:20     -334.201616        0.991624
# LBFGS:    5 15:21:20     -334.307863        0.454191
# LBFGS:    6 15:21:20     -334.329063        0.468656
# LBFGS:    7 15:21:20     -334.365997        0.546173
# LBFGS:    8 15:21:20     -334.407471        0.623766
# LBFGS:    9 15:21:20     -334.437610        0.340172
# LBFGS:   10 15:21:21     -334.449693        0.289551
# LBFGS:   11 15:21:21     -334.460455        0.297633
# LBFGS:   12 15:21:21     -334.474140        0.409112
# LBFGS:   13 15:21:21     -334.485840        0.300160
# LBFGS:   14 15:21:21     -334.493172        0.297545
# LBFGS:   15 15:21:21     -334.498386        0.184185
# LBFGS:   16 15:21:21     -334.502661        0.172219
# LBFGS:   17 15:21:21     -334.506145        0.187628
# LBFGS:   18 15:21:22     -334.509470        0.181198
# LBFGS:   19 15:21:22     -334.513719        0.216578
# LBFGS:   20 15:21:22     -334.518657        0.251597
#        Step     Time          Energy          fmax
# LBFGS:    0 15:21:22     -334.141115        1.670260
# LBFGS:    1 15:21:22     -334.174745        0.753937
# LBFGS:    2 15:21:22     -334.188146        0.363220
# LBFGS:    3 15:21:22     -334.227081        0.477617
# LBFGS:    4 15:21:22     -334.236833        0.427724
# LBFGS:    5 15:21:23     -334.243418        0.220533
# LBFGS:    6 15:21:23     -334.247902        0.214048
# LBFGS:    7 15:21:23     -334.252176        0.215822
# LBFGS:    8 15:21:23     -334.255586        0.165577
# LBFGS:    9 15:21:23     -334.258989        0.176218
# LBFGS:   10 15:21:23     -334.263058        0.250037
# LBFGS:   11 15:21:23     -334.267290        0.303349
# LBFGS:   12 15:21:24     -334.271078        0.222082
# LBFGS:   13 15:21:24     -334.274505        0.207782
# LBFGS:   14 15:21:24     -334.278066        0.208131
# LBFGS:   15 15:21:24     -334.282509        0.261225
# LBFGS:   16 15:21:24     -334.287445        0.290495
# LBFGS:   17 15:21:24     -334.291538        0.233074
# LBFGS:   18 15:21:24     -334.294315        0.128525
# LBFGS:   19 15:21:24     -334.296243        0.123187
# LBFGS:   20 15:21:25     -334.298195        0.198466
#        Step     Time          Energy          fmax
# LBFGS:    0 15:21:25     -334.367136        2.852595
# LBFGS:    1 15:21:25     -334.451711        1.751122
# LBFGS:    2 15:21:25     -334.486234        0.835419
# LBFGS:    3 15:21:25     -334.515634        0.718246
# LBFGS:    4 15:21:25     -334.581779        1.107969
# LBFGS:    5 15:21:25     -334.590805        0.622350
# LBFGS:    6 15:21:25     -334.596861        0.280277
# LBFGS:    7 15:21:26     -334.598615        0.299213
# LBFGS:    8 15:21:26     -334.604946        0.172670
# LBFGS:    9 15:21:26     -334.607776        0.209281
# LBFGS:   10 15:21:26     -334.612366        0.219552
# LBFGS:   11 15:21:26     -334.615566        0.202447
# LBFGS:   12 15:21:26     -334.618309        0.166049
# LBFGS:   13 15:21:26     -334.620643        0.143137
# LBFGS:   14 15:21:26     -334.623085        0.210225
# LBFGS:   15 15:21:27     -334.626018        0.280274
# LBFGS:   16 15:21:27     -334.628914        0.258845
# LBFGS:   17 15:21:27     -334.631349        0.172757
# LBFGS:   18 15:21:27     -334.633249        0.134923
# LBFGS:   19 15:21:27     -334.634645        0.129743
# LBFGS:   20 15:21:27     -334.635843        0.159375
#        Step     Time          Energy          fmax
# LBFGS:    0 15:21:27     -334.396601        2.161543
# LBFGS:    1 15:21:27     -334.448822        1.054668
# LBFGS:    2 15:21:28     -334.468952        0.548070
# LBFGS:    3 15:21:28     -334.507961        0.632466
# LBFGS:    4 15:21:28     -334.537672        0.883708
# LBFGS:    5 15:21:28     -334.548212        0.561108
# LBFGS:    6 15:21:28     -334.556125        0.186011
# LBFGS:    7 15:21:28     -334.558872        0.259675
# LBFGS:    8 15:21:28     -334.563761        0.228833
# LBFGS:    9 15:21:28     -334.567283        0.163509
# LBFGS:   10 15:21:29     -334.570852        0.200083
# LBFGS:   11 15:21:29     -334.573341        0.216683
# LBFGS:   12 15:21:29     -334.575222        0.165631
# LBFGS:   13 15:21:29     -334.576906        0.112880
# LBFGS:   14 15:21:29     -334.578621        0.129302
# LBFGS:   15 15:21:29     -334.580242        0.153682
# LBFGS:   16 15:21:29     -334.581489        0.140407
# LBFGS:   17 15:21:29     -334.582365        0.097057
# LBFGS:   18 15:21:30     -334.583078        0.093118
# LBFGS:   19 15:21:30     -334.583681        0.077778
# LBFGS:   20 15:21:30     -334.584255        0.090274
#        Step     Time          Energy          fmax
# LBFGS:    0 15:21:30     -333.996500        2.490288
# LBFGS:    1 15:21:30     -334.078203        1.278803
# LBFGS:    2 15:21:30     -334.146236        1.205340
# LBFGS:    3 15:21:30     -334.274715        2.167408
# LBFGS:    4 15:21:30     -334.331308        0.986549
# LBFGS:    5 15:21:31     -334.377825        0.593894
# LBFGS:    6 15:21:31     -334.446028        0.511533
# LBFGS:    7 15:21:31     -334.460274        0.515521
# LBFGS:    8 15:21:31     -334.494505        0.458458
# LBFGS:    9 15:21:31     -334.517277        0.376856
# LBFGS:   10 15:21:31     -334.529468        0.280553
# LBFGS:   11 15:21:31     -334.536098        0.243944
# LBFGS:   12 15:21:31     -334.547527        0.281722
# LBFGS:   13 15:21:32     -334.558050        0.308172
# LBFGS:   14 15:21:32     -334.566271        0.222530
# LBFGS:   15 15:21:32     -334.570961        0.189632
# LBFGS:   16 15:21:32     -334.575247        0.196575
# LBFGS:   17 15:21:32     -334.579374        0.173057
# LBFGS:   18 15:21:32     -334.582855        0.152537
# LBFGS:   19 15:21:32     -334.586422        0.167019
# LBFGS:   20 15:21:32     -334.590778        0.199029
#        Step     Time          Energy          fmax
# LBFGS:    0 15:21:33     -333.921068        2.242018
# LBFGS:    1 15:21:33     -333.974994        1.226273
# LBFGS:    2 15:21:33     -333.997019        0.586155
# LBFGS:    3 15:21:33     -334.042988        0.831985
# LBFGS:    4 15:21:33     -334.074844        0.934367
# LBFGS:    5 15:21:33     -334.089153        0.534069
# LBFGS:    6 15:21:33     -334.097238        0.234008
# LBFGS:    7 15:21:33     -334.104082        0.491718
# LBFGS:    8 15:21:34     -334.121542        0.868297
# LBFGS:    9 15:21:34     -334.145243        0.896622
# LBFGS:   10 15:21:34     -334.168081        0.541366
# LBFGS:   11 15:21:34     -334.186025        0.425227
# LBFGS:   12 15:21:34     -334.212133        0.732012
# LBFGS:   13 15:21:34     -334.243978        1.090527
# LBFGS:   14 15:21:34     -334.284885        1.109451
# LBFGS:   15 15:21:34     -334.326013        0.748725
# LBFGS:   16 15:21:35     -334.364036        0.608023
# LBFGS:   17 15:21:35     -334.395178        0.663711
# LBFGS:   18 15:21:35     -334.420318        0.490723
# LBFGS:   19 15:21:35     -334.431051        0.741292
# LBFGS:   20 15:21:35     -334.444795        0.352420
#        Step     Time          Energy          fmax
# LBFGS:    0 15:21:35     -334.019756        2.506824
# LBFGS:    1 15:21:35     -334.105177        1.305444
# LBFGS:    2 15:21:35     -334.172874        1.160150
# LBFGS:    3 15:21:36     -334.266157        2.974194
# LBFGS:    4 15:21:36     -334.377752        0.711254
# LBFGS:    5 15:21:36     -334.413002        0.633245
# LBFGS:    6 15:21:36     -334.483417        0.545490
# LBFGS:    7 15:21:36     -334.497347        0.346665
# LBFGS:    8 15:21:36     -334.514595        0.431346
# LBFGS:    9 15:21:36     -334.528147        0.462895
# LBFGS:   10 15:21:36     -334.538065        0.257359
# LBFGS:   11 15:21:37     -334.542232        0.188303
# LBFGS:   12 15:21:37     -334.546224        0.240374
# LBFGS:   13 15:21:37     -334.551025        0.347306
# LBFGS:   14 15:21:37     -334.556486        0.335910
# LBFGS:   15 15:21:37     -334.560991        0.188450
# LBFGS:   16 15:21:37     -334.564159        0.161734
# LBFGS:   17 15:21:37     -334.566725        0.166010
# LBFGS:   18 15:21:37     -334.569591        0.248926
# LBFGS:   19 15:21:38     -334.572815        0.253509
# LBFGS:   20 15:21:38     -334.576446        0.192177
#        Step     Time          Energy          fmax
# LBFGS:    0 15:21:38     -334.166471        1.633252
# LBFGS:    1 15:21:38     -334.204305        0.790558
# LBFGS:    2 15:21:38     -334.223450        0.591738
# LBFGS:    3 15:21:38     -334.300764        0.839228
# LBFGS:    4 15:21:38     -334.311630        0.544393
# LBFGS:    5 15:21:39     -334.333765        0.411686
# LBFGS:    6 15:21:39     -334.344944        0.382912
# LBFGS:    7 15:21:39     -334.359730        0.299531
# LBFGS:    8 15:21:39     -334.372564        0.336042
# LBFGS:    9 15:21:39     -334.389160        0.352764
# LBFGS:   10 15:21:39     -334.400774        0.409493
# LBFGS:   11 15:21:39     -334.408850        0.367214
# LBFGS:   12 15:21:39     -334.415455        0.283234
# LBFGS:   13 15:21:40     -334.422512        0.282633
# LBFGS:   14 15:21:40     -334.429680        0.420137
# LBFGS:   15 15:21:40     -334.433414        0.282969
# LBFGS:   16 15:21:40     -334.438288        0.222703
# LBFGS:   17 15:21:40     -334.441231        0.224396
# LBFGS:   18 15:21:40     -334.445219        0.198265
# LBFGS:   19 15:21:40     -334.448835        0.193995
# LBFGS:   20 15:21:40     -334.453049        0.300850
#        Step     Time          Energy          fmax
# LBFGS:    0 15:21:41     -334.338625        2.603666
# LBFGS:    1 15:21:41     -334.408628        1.486375
# LBFGS:    2 15:21:41     -334.434883        0.599442
# LBFGS:    3 15:21:41     -334.456714        0.543855
# LBFGS:    4 15:21:41     -334.507133        0.986853
# LBFGS:    5 15:21:41     -334.516594        0.617320
# LBFGS:    6 15:21:41     -334.524139        0.267052
# LBFGS:    7 15:21:41     -334.526644        0.307752
# LBFGS:    8 15:21:42     -334.532516        0.200297
# LBFGS:    9 15:21:42     -334.535293        0.160177
# LBFGS:   10 15:21:42     -334.539303        0.210905
# LBFGS:   11 15:21:42     -334.542641        0.263253
# LBFGS:   12 15:21:42     -334.545492        0.187122
# LBFGS:   13 15:21:42     -334.547764        0.139682
# LBFGS:   14 15:21:42     -334.549967        0.165029
# LBFGS:   15 15:21:42     -334.552559        0.268099
# LBFGS:   16 15:21:43     -334.555342        0.275143
# LBFGS:   17 15:21:43     -334.557611        0.190358
# LBFGS:   18 15:21:43     -334.559349        0.136105
# LBFGS:   19 15:21:43     -334.560753        0.117428
# LBFGS:   20 15:21:43     -334.562208        0.182235
#        Step     Time          Energy          fmax
# LBFGS:    0 15:21:43     -334.060760        1.765678
# LBFGS:    1 15:21:43     -334.108480        0.830127
# LBFGS:    2 15:21:43     -334.131088        0.643145
# LBFGS:    3 15:21:44     -334.216320        0.759600
# LBFGS:    4 15:21:44     -334.244049        0.792188
# LBFGS:    5 15:21:44     -334.269262        0.583671
# LBFGS:    6 15:21:44     -334.287828        0.448193
# LBFGS:    7 15:21:44     -334.313042        0.765149
# LBFGS:    8 15:21:44     -334.339796        0.864524
# LBFGS:    9 15:21:44     -334.362697        0.659597
# LBFGS:   10 15:21:44     -334.378605        0.387285
# LBFGS:   11 15:21:45     -334.388315        0.314529
# LBFGS:   12 15:21:45     -334.396066        0.335840
# LBFGS:   13 15:21:45     -334.410618        0.501265
# LBFGS:   14 15:21:45     -334.426376        0.423611
# LBFGS:   15 15:21:45     -334.439987        0.381364
# LBFGS:   16 15:21:45     -334.450134        0.349517
# LBFGS:   17 15:21:45     -334.458858        0.305763
# LBFGS:   18 15:21:45     -334.468096        0.344283
# LBFGS:   19 15:21:46     -334.477762        0.300965
# LBFGS:   20 15:21:46     -334.485721        0.279423

# %%
top_candidates = outputs["adslabs"]
global_min_candidate = top_candidates[0]

# %%
top_candidates = outputs["adslabs"]
pd.DataFrame(top_candidates)
# Out:
#                                          input_atoms  \
# 0  {'atoms': (Atom('Cu', [np.float64(1.3000465215...
# 1  {'atoms': (Atom('Cu', [np.float64(1.3000465215...
# 2  {'atoms': (Atom('Cu', [np.float64(1.3000465215...
# 3  {'atoms': (Atom('Cu', [np.float64(1.3000465215...
# 4  {'atoms': (Atom('Cu', [np.float64(1.3000465215...
# 5  {'atoms': (Atom('Cu', [np.float64(1.3000465215...
# 6  {'atoms': (Atom('Cu', [np.float64(1.3000465215...
# 7  {'atoms': (Atom('Cu', [np.float64(1.3000465215...
# 8  {'atoms': (Atom('Cu', [np.float64(1.3000465215...
# 9  {'atoms': (Atom('Cu', [np.float64(1.3000465215...
#
#                                                atoms  \
# 0  (Atom('Cu', [np.float64(1.3000465215529724), n...
# 1  (Atom('Cu', [np.float64(1.3000465215529724), n...
# 2  (Atom('Cu', [np.float64(1.3000465215529724), n...
# 3  (Atom('Cu', [np.float64(1.3000465215529724), n...
# 4  (Atom('Cu', [np.float64(1.3000465215529724), n...
# 5  (Atom('Cu', [np.float64(1.3000465215529724), n...
# 6  (Atom('Cu', [np.float64(1.3000465215529724), n...
# 7  (Atom('Cu', [np.float64(1.3000465215529724), n...
# 8  (Atom('Cu', [np.float64(1.3000465215529724), n...
# 9  (Atom('Cu', [np.float64(1.3000465215529724), n...
#
#                                              results
# 0  {'energy': -334.6358430925115, 'forces': [[0.0...
# 1  {'energy': -334.59077816636403, 'forces': [[0....
# 2  {'energy': -334.58425503404, 'forces': [[0.0, ...
# 3  {'energy': -334.5764463487371, 'forces': [[0.0...
# 4  {'energy': -334.56220799119313, 'forces': [[0....
# 5  {'energy': -334.5186574998601, 'forces': [[0.0...
# 6  {'energy': -334.4857214036687, 'forces': [[0.0...
# 7  {'energy': -334.4530485215888, 'forces': [[0.0...
# 8  {'energy': -334.4447954240544, 'forces': [[0.0...
# 9  {'energy': -334.29819470078786, 'forces': [[0....

# %% [markdown]
# # Write VASP input files
#
# This assumes you have access to VASP pseudopotentials. The default VASP flags (which are equivalent to those used to make OC20) are located in `ocdata.utils.vasp`. Alternatively, you may pass your own vasp flags to the `write_vasp_input_files` function as `vasp_flags`

# %%
# Grab the 5 systems with the lowest energy
top_5_candidates = top_candidates[:5]

# Write the inputs
for idx, config in enumerate(top_5_candidates):
    os.makedirs(f"data/{idx}", exist_ok=True)
    write_vasp_input_files(config["atoms"], outdir = f"data/{idx}/")
